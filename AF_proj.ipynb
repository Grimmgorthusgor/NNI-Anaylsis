# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('NNI_Index.csv')
df
# Out:
#                        Country Name Country Code  \
# 0                       Afghanistan          AFG
# 1                            Angola          AGO
# 2                           Albania          ALB
# 3              United Arab Emirates          ARE
# 4                         Argentina          ARG
# 5                           Armenia          ARM
# 6                         Australia          AUS
# 7                           Austria          AUT
# 8                        Azerbaijan          AZE
# 9                           Burundi          BDI
# 10                          Belgium          BEL
# 11                            Benin          BEN
# 12                     Burkina Faso          BFA
# 13                       Bangladesh          BGD
# 14                         Bulgaria          BGR
# 15                          Bahrain          BHR
# 16                     Bahamas, The          BHS
# 17           Bosnia and Herzegovina          BIH
# ...

# %%
"France" in df["Country Name"].values
# Out:
# True

# %%
country = input("Choose a country (Format: Argentina): " )
while country not in df["Country Name"].values:
    print("Country not found")
    country = input("Choose a country (Format: Argentina): " )
# Out:
# Choose a country (Format: Argentina):
# Country not found
# Choose a country (Format: Argentina):
# Country not found
# Choose a country (Format: Argentina):
# Country not found
# Choose a country (Format: Argentina): France

# %%
country_row = df[df["Country Name"] == country].iloc[:,3:13]
yoy_nni_country = country_row.values[0]

# %%
country_row.columns.values
# Out:
# array(['2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
#        '2015', '2016'], dtype=object)

# %%
year_nni_country = country_row.T.index == yoy_nni_country.min()
min_year_country = country_row.T.index[yoy_nni_country == yoy_nni_country.min()].values[0]
max_year_country = country_row.T.index[yoy_nni_country == yoy_nni_country.max()].values[0]

# %%
print("\n{} is the year with the min NNI at: {:.3E}".format(min_year_country,yoy_nni_country.min()))
# Out:
# 2015 is the year with the min NNI at: 2.035E+12

# %%
print("\n{} is the year with the max NNi at: {:.3E}".format(max_year_country,yoy_nni_country.max()))
# Out:
# 2008 is the year with the max NNi at: 2.484E+12

# %%
"{:.3E}".format(yoy_nni_country.mean())
# Out:
# '2.272E+12'

# %%
"{:.3E}".format(np.median(yoy_nni_country))
# Out:
# '2.269E+12'

# %%
CAGR = "{:.3f}%".format((yoy_nni_country[-1] / yoy_nni_country[0]) ** (1/10) - 1)
CAGR
# Out:
# '-0.010%'

# %%
year = input("Choose a year (Format: XXXX): " )
# Out:
# Choose a year (Format: XXXX): 2012

# %%
max_year = df[["Country Name", year]][df[year] == df[year].max()]
max_country = max_year["Country Name"].values[0]

"{}, {:.3E}".format(max_country, max_year[year].values[0])
# Out:
# 'United States, 1.400E+13'

# %%
min_year = df[["Country Name", year]][df[year] == df[year].min()]
min_country = min_year["Country Name"].values[0]

"{}, {:.3E}".format(min_country, min_year[year].values[0])
# Out:
# 'Sao Tome and Principe, 1.438E+08'

# %%
"This is the mean: {:.3E}".format(df[year].mean())
# Out:
# 'This is the mean: 3.825E+11'

# %%
"This is the median: {:.3E}".format(df[year].median())
# Out:
# 'This is the median: 3.043E+10'
